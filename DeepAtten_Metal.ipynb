# %% [markdown]
# ## PARAM

# %%
import numpy as np
import pandas as pd
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras import layers
import torch
import math
import pickle
import numpy as np
from sklearn.model_selection import KFold
from tqdm import tqdm 
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset

# %%
SEQ_LENGTH = 15 
NUM_FEATURE = 1024 
HIDDEN_DIM = 512          # Adjusted for balance between complexity and generalization
BATCH_SIZE = 32            # Moderate batch size for stable training
NUM_HEADS = 8              # Reverted to original for better feature diversity
NUM_ENCODER_LAYERS = 2     # Reduced to avoid overfitting on positive class
DROPOUT = 0.2   
EPOCHS = 25 
K_FOLD=5
NUM_CLASSES = 2
VALIDATION_MODE="independent" # cross or independent

# %%
import numpy as np
x_train = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/train_data.npy", allow_pickle=True)
y_train = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/train_labels.npy", allow_pickle=True)
x_test = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/test_data.npy", allow_pickle=True)
y_test = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/test_labels.npy", allow_pickle=True)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test .shape)
# Out:
# (86214, 1, 15, 1024)
# (86214, 2)
# (21208, 1, 15, 1024)
# (21208, 2)

# %%
# Define the Data Generator
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, data, labels, batch_size):
        self.data = data
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.data))

    def __len__(self):
        return int(np.ceil(len(self.data) / self.batch_size))

    def __getitem__(self, index):
        batch_indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        batch_data = [self.data[i].squeeze() for i in batch_indexes]  # Squeeze to (15, 1024)
        batch_labels = [self.labels[i] for i in batch_indexes]        # Collect labels without flattening
        return np.array(batch_data), np.array(batch_labels)           # Correct shape for both data and labels

# %% [markdown]
# ## Model Defination code

# %%
import tensorflow as tf
from tensorflow.keras import layers

class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, max_len=SEQ_LENGTH, embed_dim=NUM_FEATURE):
        super(PositionalEncoding, self).__init__()
        self.positional_encoding = self.positional_encoding(max_len, embed_dim)

    def positional_encoding(self, max_len, embed_dim):
        pos = tf.range(max_len, dtype=tf.float32)[:, tf.newaxis]  # (max_len, 1)
        i = tf.range(embed_dim)[tf.newaxis, :]  # (1, embed_dim)
        angle_rates = 1 / tf.pow(10000.0, (2 * tf.cast(i // 2, tf.float32)) / tf.cast(embed_dim, tf.float32))
        angle_rads = pos * angle_rates  # (max_len, embed_dim)

        # Create sine and cosine encodings
        angle_rads_even = tf.sin(angle_rads[:, 0::2])  # Apply to even indices
        angle_rads_odd = tf.cos(angle_rads[:, 1::2])   # Apply to odd indices

        # Create a new tensor to hold the combined results
        angle_rads_combined = tf.zeros_like(angle_rads)  # Initialize tensor of the same shape
        angle_rads_combined = angle_rads_combined.numpy()  # Convert to NumPy for assignment
        angle_rads_combined[:, 0::2] = angle_rads_even.numpy()  # Assign sine values to even indices
        angle_rads_combined[:, 1::2] = angle_rads_odd.numpy()   # Assign cosine values to odd indices

        return tf.convert_to_tensor(angle_rads_combined, dtype=tf.float32)[tf.newaxis, ...]  # Add batch dimension

    def call(self, inputs):
        return inputs + self.positional_encoding[:, :tf.shape(inputs)[1], :]

class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, num_hidden, num_heads):
        super(SelfAttention, self).__init__()
        self.num_heads = num_heads
        self.attention_head_size = num_hidden // num_heads
        self.all_head_size = num_heads * self.attention_head_size

        self.q_dense = layers.Dense(self.all_head_size)
        self.k_dense = layers.Dense(self.all_head_size)
        self.v_dense = layers.Dense(self.all_head_size)
        self.softmax = layers.Softmax(axis=-1)

    def call(self, q, k, v, mask=None):
        q = self.q_dense(q)
        k = self.k_dense(k)
        v = self.v_dense(v)

        q = tf.reshape(q, (-1, tf.shape(q)[1], self.num_heads, self.attention_head_size))
        k = tf.reshape(k, (-1, tf.shape(k)[1], self.num_heads, self.attention_head_size))
        v = tf.reshape(v, (-1, tf.shape(v)[1], self.num_heads, self.attention_head_size))

        q = tf.transpose(q, perm=[0, 2, 1, 3])
        k = tf.transpose(k, perm=[0, 2, 1, 3])
        v = tf.transpose(v, perm=[0, 2, 1, 3])

        attention_scores = tf.matmul(q, k, transpose_b=True) / tf.math.sqrt(float(self.attention_head_size))
        if mask is not None:
            attention_scores += (mask * -1e9)
        attention_probs = self.softmax(attention_scores)
        context_layer = tf.matmul(attention_probs, v)

        context_layer = tf.transpose(context_layer, perm=[0, 2, 1, 3])
        context_layer = tf.reshape(context_layer, (-1, tf.shape(context_layer)[1], self.all_head_size))
        return context_layer

class PositionalAttention(tf.keras.Model):
    def __init__(self, feature_dim, hidden_dim, num_heads, num_classes, dropout_rate):
        super(PositionalAttention, self).__init__()
        self.positional_encoding = PositionalEncoding(max_len=SEQ_LENGTH, embed_dim=feature_dim)
        self.input_block = tf.keras.Sequential([
            layers.LayerNormalization(epsilon=1e-6),
            layers.Dense(hidden_dim, activation='relu'),
            layers.Dropout(dropout_rate)
        ])
        self.attention = SelfAttention(hidden_dim, num_heads)
        self.feed_forward = tf.keras.Sequential([
            layers.Dense(hidden_dim, activation='relu'),
            layers.Dropout(dropout_rate),
            layers.Dense(hidden_dim, activation='relu')
        ])
        self.pooling = layers.GlobalAveragePooling1D()
        self.output_layer = layers.Dense(num_classes, activation='softmax')

    def call(self, inputs, mask=None):
        if len(inputs.shape) != 3:
            raise ValueError(f"Expected input to have shape (batch_size, seq_length, num_features), but got {inputs.shape}.")
        
        # Apply positional encoding
        x = self.positional_encoding(inputs)
        x = self.input_block(x)
        x = self.attention(x, x, x, mask)
        x = self.feed_forward(x)
        x = self.pooling(x)
        output = self.output_layer(x)
        return output

# %%
# Function to save ROC values
def SAVEROC(fpr, tpr, auc, model_name):
    roc_data = {'fpr': fpr, 'tpr': tpr, 'auc': auc}
    file_path = f"C:/jupyter/Malik/Metal Binding/Code/Roc/{model_name}.pkl"
    with open(file_path, 'wb') as f:
        pickle.dump(roc_data, f)
    print(f"ROC values saved to {file_path}")

def model_test(model, x_test, y_test, model_name):
    print(f'Test data shape: {x_test.shape}')
    
    # Get model predictions and select the positive class probabilities
    pred_test = model.predict(x_test)[:, 1]  # Use the positive class probabilities for binary ROC

    # Compute ROC curve and AUC for binary classification
    fpr, tpr, thresholds = metrics.roc_curve(y_test[:, 1], pred_test)  # y_test[:, 1] gives true positive labels
    AUC = metrics.auc(fpr, tpr)
    
    # Display ROC curve
    display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=AUC, estimator_name=' PositionalAttentionModel')
    display.plot()
    
    # Save ROC values
    SAVEROC(fpr, tpr, AUC, model_name)
    
    # Calculate G-Mean to find the optimal threshold
    gmeans = np.sqrt(tpr * (1 - fpr))
    ix = np.argmax(gmeans)
    best_threshold = thresholds[ix]
    print(f'Best Threshold={best_threshold}, G-Mean={gmeans[ix]}')
    
    # Apply threshold to get binary predictions
    y_pred = (pred_test >= best_threshold).astype(int)
    
    # Compute confusion matrix and metrics
    TN, FP, FN, TP = metrics.confusion_matrix(y_test[:, 1], y_pred).ravel()  # y_test[:, 1] for true positive class
    Sens = TP / (TP + FN) if (TP + FN) > 0 else 0.0
    Spec = TN / (FP + TN) if (FP + TN) > 0 else 0.0
    Acc = (TP + TN) / (TP + FP + TN + FN)
    Precision = TP / (TP + FP) if (TP + FP) > 0 else 0.0
    MCC = ((TP * TN) - (FP * FN)) / math.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN)) \
          if (TP + FP > 0 and TP + FN > 0 and TN + FP > 0 and TN + FN > 0) else 0.0
    F1 = 2 * Precision * Sens / (Precision + Sens) if (Precision + Sens) > 0 else 0.0

    # Print results
    print(f'TP={TP}, FP={FP}, TN={TN}, FN={FN}, Sensitivity={Sens:.4f}, '
          f'Specificity={Spec:.4f}, Accuracy={Acc:.4f}, Precision={Precision:.4f}, '
          f'F1={F1:.4f}, MCC={MCC:.4f}, AUC={AUC:.4f}\n')

    return TP, FP, TN, FN, Sens, Spec, Acc, MCC, AUC, F1, Precision

# %% [markdown]
# ## Independent Test Set

# %%
# Training code
if VALIDATION_MODE == "independent":
    # Check the shape of y_train
    print("Shape of y_train:", y_train.shape)

    # Initialize the data generator with the batch size
    generator = DataGenerator(x_train, y_train, batch_size=BATCH_SIZE)

    # Instantiate the AttentionOnlyModel
    model = PositionalAttention(
        feature_dim=NUM_FEATURE,     # Input feature dimension (1024)
        hidden_dim=HIDDEN_DIM,       # Hidden dimension for model
        num_heads=NUM_HEADS,         # Number of attention heads
        num_classes=NUM_CLASSES,     # Number of output classes (2)
        dropout_rate=DROPOUT         # Dropout rate
    )

    # Compile the model with categorical_crossentropy for one-hot encoded labels
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Build the model with the input shape expected by the DataGenerator
    model.build(input_shape=(BATCH_SIZE, SEQ_LENGTH, NUM_FEATURE))
    
    model.summary()

    # Train the model
    history = model.fit(generator, epochs=EPOCHS, verbose=1)

# Test the model
if VALIDATION_MODE == "independent":
    x_test_reshaped = x_test.reshape(-1, 15, 1024)  # Adjust this shape as needed
    print(f"Reshaped Test data shape: {x_test_reshaped.shape}")
    # Run the model test function directly with one-hot encoded y_test
    model_name = "PATN" 
    model_test(model, x_test_reshaped, y_test, model_name)
# Out:
# Shape of y_train: (86214, 2)
# Model: "positional_attention_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_1 (Posi  multiple                 0
#  tionalEncoding)
#
#  sequential_2 (Sequential)   (32, 15, 512)             526848
#
#  self_attention_1 (SelfAtten  multiple                 787968
#  tion)
#
#  sequential_3 (Sequential)   (32, 15, 512)             525312
#
#  global_average_pooling1d_1   multiple                 0
#  (GlobalAveragePooling1D)
#
#  dense_13 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.1451 - accuracy: 0.9685
# Epoch 2/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.1148 - accuracy: 0.9698
# Epoch 3/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.1049 - accuracy: 0.9721
# Epoch 4/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.0967 - accuracy: 0.9751
# Epoch 5/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0994 - accuracy: 0.9741
# Epoch 6/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0949 - accuracy: 0.9754
# Epoch 7/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0949 - accuracy: 0.9752
# Epoch 8/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0935 - accuracy: 0.9758
# Epoch 9/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0915 - accuracy: 0.9765
# Epoch 10/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0904 - accuracy: 0.9766
# Epoch 11/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.0918 - accuracy: 0.9748
# Epoch 12/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.0962 - accuracy: 0.9729
# Epoch 13/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0922 - accuracy: 0.9743
# Epoch 14/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0949 - accuracy: 0.9706
# Epoch 15/25
# 2695/2695 [==============================] - 26s 10ms/step - loss: 0.0952 - accuracy: 0.9742
# Epoch 16/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0869 - accuracy: 0.9767
# Epoch 17/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.0896 - accuracy: 0.9760
# Epoch 18/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0880 - accuracy: 0.9767
# Epoch 19/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.0857 - accuracy: 0.9772
# Epoch 20/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.0849 - accuracy: 0.9777
# Epoch 21/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.0841 - accuracy: 0.9776
# Epoch 22/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0828 - accuracy: 0.9782
# Epoch 23/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.0817 - accuracy: 0.9787
# Epoch 24/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.0823 - accuracy: 0.9781
# Epoch 25/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.0812 - accuracy: 0.9790
# Reshaped Test data shape: (21208, 15, 1024)
# Test data shape: (21208, 15, 1024)
# 663/663 [==============================] - 2s 3ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/PATN.pkl
# Best Threshold=0.07031849771738052, G-Mean=0.8047784690515922
# TP=451, FP=1842, TN=18732, FN=183, Sensitivity=0.7114, Specificity=0.9105, Accuracy=0.9045, Precision=0.1967, F1=0.3082, MCC=0.3410, AUC=0.8828

# %% [markdown]
# ## Cross-Validation

# %%
# Training code for the Cross-validation
if VALIDATION_MODE == "cross":
    # Check the shape of y_train
    print("Shape of y_train:", y_train.shape)

    # Initialize KFold
    kf = KFold(n_splits=K_FOLD, shuffle=True, random_state=42)

    # Store metrics for each fold
    metrics_list = []

    # Cross-validation loop
    for train_index, val_index in kf.split(x_train):
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

        # Print shapes for debugging
        print(f"Training on fold with shapes: {x_train_fold.shape}, {y_train_fold.shape}")
        print(f"Validation on fold with shapes: {x_val_fold.shape}, {y_val_fold.shape}")

        # Initialize the data generator for the training data
        generator = DataGenerator(x_train_fold, y_train_fold, batch_size=BATCH_SIZE)

        # Instantiate the AttentionOnlyModel
        model = PositionalAttention(
            feature_dim=NUM_FEATURE,     # Input feature dimension (1024)
            hidden_dim=HIDDEN_DIM,       # Hidden dimension for model
            num_heads=NUM_HEADS,         # Number of attention heads
            num_classes=NUM_CLASSES,     # Number of output classes (2)
            dropout_rate=DROPOUT         # Dropout rate
        )

        # Compile the model
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Build the model with the input shape expected by the DataGenerator
        model.build(input_shape=(BATCH_SIZE, SEQ_LENGTH, NUM_FEATURE))
        
        model.summary()

        # Train the model
        history = model.fit(generator, epochs=EPOCHS, verbose=1)  # Set verbose to 1 to see training progress

        # Reshape validation data before testing
        x_val_reshaped = x_val_fold.reshape(-1, 15, 1024)  # Adjust this shape to match model input
        print(f"Reshaped Validation data shape: {x_val_reshaped.shape}")

        # Evaluate the model on the validation set using the model test function
        model_name = f"AttentionOnlyModel_fold_{len(metrics_list) + 1}"  # Create a unique name for the model
        metrics_result = model_test(model, x_val_reshaped, y_val_fold, model_name)  # Ensure y_val_fold is one-hot encoded if necessary

        # Store metrics for averaging
        metrics_list.append(metrics_result)

    # Compute average metrics
    average_metrics = np.mean(metrics_list, axis=0)

    print(f"Average metrics over {K_FOLD} folds:")
    print(f"TP={average_metrics[0]}, FP={average_metrics[1]}, TN={average_metrics[2]}, FN={average_metrics[3]}")
    print(f"Sensitivity={average_metrics[4]:.4f}, Specificity={average_metrics[5]:.4f}, "
          f"Accuracy={average_metrics[6]:.4f}, Precision={average_metrics[7]:.4f}, "
          f"F1={average_metrics[8]:.4f}, MCC={average_metrics[9]:.4f}, AUC={average_metrics[10]:.4f}")
# Out:
# Shape of y_train: (86214, 2)
# Training on fold with shapes: (68971, 1, 15, 1024), (68971, 2)
# Validation on fold with shapes: (17243, 1, 15, 1024), (17243, 2)
# Model: "attention_only_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding (Positi  multiple                 0
#  onalEncoding)
#
#  sequential (Sequential)     (32, 15, 512)             526848
#
#  self_attention (SelfAttenti  multiple                 787968
#  on)
#
#  sequential_1 (Sequential)   (32, 15, 512)             525312
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dense_6 (Dense)             multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1408 - accuracy: 0.9693
# Epoch 2/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.1244 - accuracy: 0.9698
# Epoch 3/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1206 - accuracy: 0.9697
# Epoch 4/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.1145 - accuracy: 0.9698
# Epoch 5/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1106 - accuracy: 0.9698
# Epoch 6/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.1088 - accuracy: 0.9700
# Epoch 7/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1093 - accuracy: 0.9698
# Epoch 8/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1037 - accuracy: 0.9711
# Epoch 9/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1013 - accuracy: 0.9714
# Epoch 10/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1009 - accuracy: 0.9722
# Epoch 11/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0973 - accuracy: 0.9734
# Epoch 12/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0969 - accuracy: 0.9727
# Epoch 13/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0948 - accuracy: 0.9747
# Epoch 14/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0972 - accuracy: 0.9740
# Epoch 15/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0943 - accuracy: 0.9739
# Epoch 16/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0948 - accuracy: 0.9744
# Epoch 17/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0927 - accuracy: 0.9746
# Epoch 18/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0922 - accuracy: 0.9748
# Epoch 19/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0916 - accuracy: 0.9747
# Epoch 20/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0921 - accuracy: 0.9752
# Epoch 21/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0902 - accuracy: 0.9751
# Epoch 22/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0907 - accuracy: 0.9749
# Epoch 23/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0921 - accuracy: 0.9742
# Epoch 24/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0892 - accuracy: 0.9755
# Epoch 25/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0891 - accuracy: 0.9756
# Reshaped Validation data shape: (17243, 15, 1024)
# Test data shape: (17243, 15, 1024)
# 539/539 [==============================] - 2s 4ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/AttentionOnlyModel_fold_1.pkl
# Best Threshold=0.052065227180719376, G-Mean=0.7854500441952535
# TP=421, FP=3461, TN=13241, FN=120, Sensitivity=0.7782, Specificity=0.7928, Accuracy=0.7923, Precision=0.1084, F1=0.1904, MCC=0.2383, AUC=0.8662
#
# Training on fold with shapes: (68971, 1, 15, 1024), (68971, 2)
# Validation on fold with shapes: (17243, 1, 15, 1024), (17243, 2)
# Model: "attention_only_model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_1 (Posi  multiple                 0
#  tionalEncoding)
#
#  sequential_2 (Sequential)   (32, 15, 512)             526848
#
#  self_attention_1 (SelfAtten  multiple                 787968
#  tion)
#
#  sequential_3 (Sequential)   (32, 15, 512)             525312
#
#  global_average_pooling1d_1   multiple                 0
#  (GlobalAveragePooling1D)
#
#  dense_13 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 20s 9ms/step - loss: 0.1410 - accuracy: 0.9698
# Epoch 2/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.1210 - accuracy: 0.9699
# Epoch 3/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.1165 - accuracy: 0.9696
# Epoch 4/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.1071 - accuracy: 0.9701
# Epoch 5/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1084 - accuracy: 0.9699
# Epoch 6/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1044 - accuracy: 0.9709
# Epoch 7/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.1042 - accuracy: 0.9715
# Epoch 8/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.1026 - accuracy: 0.9719
# Epoch 9/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1035 - accuracy: 0.9728
# Epoch 10/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0998 - accuracy: 0.9731
# Epoch 11/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0989 - accuracy: 0.9731
# Epoch 12/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0979 - accuracy: 0.9738
# Epoch 13/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0978 - accuracy: 0.9737
# Epoch 14/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0966 - accuracy: 0.9741
# Epoch 15/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0952 - accuracy: 0.9740
# Epoch 16/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0948 - accuracy: 0.9746
# Epoch 17/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0938 - accuracy: 0.9747
# Epoch 18/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0920 - accuracy: 0.9747
# Epoch 19/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0965 - accuracy: 0.9738
# Epoch 20/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0914 - accuracy: 0.9748
# Epoch 21/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0930 - accuracy: 0.9750
# Epoch 22/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0927 - accuracy: 0.9748
# Epoch 23/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0920 - accuracy: 0.9750
# Epoch 24/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0912 - accuracy: 0.9744
# Epoch 25/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0910 - accuracy: 0.9744
# Reshaped Validation data shape: (17243, 15, 1024)
# Test data shape: (17243, 15, 1024)
# 539/539 [==============================] - 2s 3ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/AttentionOnlyModel_fold_2.pkl
# Best Threshold=0.08192415535449982, G-Mean=0.7999503739528943
# TP=424, FP=3014, TN=13686, FN=119, Sensitivity=0.7808, Specificity=0.8195, Accuracy=0.8183, Precision=0.1233, F1=0.2130, MCC=0.2624, AUC=0.8769
#
# Training on fold with shapes: (68971, 1, 15, 1024), (68971, 2)
# Validation on fold with shapes: (17243, 1, 15, 1024), (17243, 2)
# Model: "attention_only_model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_2 (Posi  multiple                 0
#  tionalEncoding)
#
#  sequential_4 (Sequential)   (32, 15, 512)             526848
#
#  self_attention_2 (SelfAtten  multiple                 787968
#  tion)
#
#  sequential_5 (Sequential)   (32, 15, 512)             525312
#
#  global_average_pooling1d_2   multiple                 0
#  (GlobalAveragePooling1D)
#
#  dense_20 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 20s 9ms/step - loss: 0.1449 - accuracy: 0.9688
# Epoch 2/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.1244 - accuracy: 0.9695
# Epoch 3/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.1214 - accuracy: 0.9695
# Epoch 4/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1137 - accuracy: 0.9693
# Epoch 5/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1122 - accuracy: 0.9695
# Epoch 6/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1089 - accuracy: 0.9693
# Epoch 7/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.1055 - accuracy: 0.9701
# Epoch 8/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.1083 - accuracy: 0.9698
# Epoch 9/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.1017 - accuracy: 0.9720
# Epoch 10/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0975 - accuracy: 0.9734
# Epoch 11/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0937 - accuracy: 0.9748
# Epoch 12/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0938 - accuracy: 0.9747
# Epoch 13/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0939 - accuracy: 0.9744
# Epoch 14/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0955 - accuracy: 0.9746
# Epoch 15/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0914 - accuracy: 0.9754
# Epoch 16/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0902 - accuracy: 0.9756
# Epoch 17/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0902 - accuracy: 0.9759
# Epoch 18/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0885 - accuracy: 0.9763
# Epoch 19/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0860 - accuracy: 0.9766
# Epoch 20/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0896 - accuracy: 0.9764
# Epoch 21/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0852 - accuracy: 0.9774
# Epoch 22/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0845 - accuracy: 0.9776
# Epoch 23/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0836 - accuracy: 0.9777
# Epoch 24/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0853 - accuracy: 0.9777
# Epoch 25/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0849 - accuracy: 0.9778
# Reshaped Validation data shape: (17243, 15, 1024)
# Test data shape: (17243, 15, 1024)
# 539/539 [==============================] - 2s 4ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/AttentionOnlyModel_fold_3.pkl
# Best Threshold=0.11079709976911545, G-Mean=0.8109796005921562
# TP=397, FP=2484, TN=14245, FN=117, Sensitivity=0.7724, Specificity=0.8515, Accuracy=0.8492, Precision=0.1378, F1=0.2339, MCC=0.2844, AUC=0.8936
#
# Training on fold with shapes: (68971, 1, 15, 1024), (68971, 2)
# Validation on fold with shapes: (17243, 1, 15, 1024), (17243, 2)
# Model: "attention_only_model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_3 (Posi  multiple                 0
#  tionalEncoding)
#
#  sequential_6 (Sequential)   (32, 15, 512)             526848
#
#  self_attention_3 (SelfAtten  multiple                 787968
#  tion)
#
#  sequential_7 (Sequential)   (32, 15, 512)             525312
#
#  global_average_pooling1d_3   multiple                 0
#  (GlobalAveragePooling1D)
#
#  dense_27 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 20s 9ms/step - loss: 0.1439 - accuracy: 0.9684
# Epoch 2/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1223 - accuracy: 0.9691
# Epoch 3/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1160 - accuracy: 0.9692
# Epoch 4/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1076 - accuracy: 0.9701
# Epoch 5/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.1028 - accuracy: 0.9719
# Epoch 6/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0990 - accuracy: 0.9734
# Epoch 7/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1023 - accuracy: 0.9731
# Epoch 8/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.1024 - accuracy: 0.9721
# Epoch 9/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0952 - accuracy: 0.9743
# Epoch 10/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0934 - accuracy: 0.9752
# Epoch 11/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0907 - accuracy: 0.9766
# Epoch 12/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0902 - accuracy: 0.9760
# Epoch 13/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0879 - accuracy: 0.9766
# Epoch 14/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0874 - accuracy: 0.9778
# Epoch 15/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0889 - accuracy: 0.9767
# Epoch 16/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0877 - accuracy: 0.9775
# Epoch 17/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0845 - accuracy: 0.9780
# Epoch 18/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0847 - accuracy: 0.9775
# Epoch 19/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0842 - accuracy: 0.9783
# Epoch 20/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0832 - accuracy: 0.9783
# Epoch 21/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0824 - accuracy: 0.9788
# Epoch 22/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0830 - accuracy: 0.9784
# Epoch 23/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0824 - accuracy: 0.9779
# Epoch 24/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0797 - accuracy: 0.9788
# Epoch 25/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0798 - accuracy: 0.9787
# Reshaped Validation data shape: (17243, 15, 1024)
# Test data shape: (17243, 15, 1024)
# 539/539 [==============================] - 2s 4ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/AttentionOnlyModel_fold_4.pkl
# Best Threshold=0.06368663161993027, G-Mean=0.7971199406690924
# TP=366, FP=2414, TN=14336, FN=127, Sensitivity=0.7424, Specificity=0.8559, Accuracy=0.8526, Precision=0.1317, F1=0.2236, MCC=0.2711, AUC=0.8793
#
# Training on fold with shapes: (68972, 1, 15, 1024), (68972, 2)
# Validation on fold with shapes: (17242, 1, 15, 1024), (17242, 2)
# Model: "attention_only_model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_4 (Posi  multiple                 0
#  tionalEncoding)
#
#  sequential_8 (Sequential)   (32, 15, 512)             526848
#
#  self_attention_4 (SelfAtten  multiple                 787968
#  tion)
#
#  sequential_9 (Sequential)   (32, 15, 512)             525312
#
#  global_average_pooling1d_4   multiple                 0
#  (GlobalAveragePooling1D)
#
#  dense_34 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 20s 9ms/step - loss: 0.1405 - accuracy: 0.9697
# Epoch 2/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1247 - accuracy: 0.9697
# Epoch 3/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1187 - accuracy: 0.9695
# Epoch 4/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1155 - accuracy: 0.9696
# Epoch 5/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1079 - accuracy: 0.9702
# Epoch 6/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1024 - accuracy: 0.9717
# Epoch 7/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0976 - accuracy: 0.9738
# Epoch 8/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0994 - accuracy: 0.9735
# Epoch 9/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0969 - accuracy: 0.9745
# Epoch 10/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1014 - accuracy: 0.9736
# Epoch 11/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0967 - accuracy: 0.9744
# Epoch 12/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0935 - accuracy: 0.9758
# Epoch 13/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0946 - accuracy: 0.9756
# Epoch 14/25
# 2156/2156 [==============================] - 17s 8ms/step - loss: 0.0926 - accuracy: 0.9760
# Epoch 15/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0942 - accuracy: 0.9755
# Epoch 16/25
# 2156/2156 [==============================] - 18s 9ms/step - loss: 0.0989 - accuracy: 0.9737
# Epoch 17/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0965 - accuracy: 0.9750
# Epoch 18/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.1007 - accuracy: 0.9736
# Epoch 19/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0978 - accuracy: 0.9748
# Epoch 20/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0917 - accuracy: 0.9757
# Epoch 21/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0917 - accuracy: 0.9754
# Epoch 22/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0914 - accuracy: 0.9758
# Epoch 23/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0894 - accuracy: 0.9757
# Epoch 24/25
# 2156/2156 [==============================] - 19s 9ms/step - loss: 0.0873 - accuracy: 0.9769
# Epoch 25/25
# 2156/2156 [==============================] - 18s 8ms/step - loss: 0.0894 - accuracy: 0.9770
# Reshaped Validation data shape: (17242, 15, 1024)
# Test data shape: (17242, 15, 1024)
# 539/539 [==============================] - 2s 3ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/AttentionOnlyModel_fold_5.pkl
# Best Threshold=0.05015694722533226, G-Mean=0.8105209937848651
# TP=406, FP=2380, TN=14332, FN=124, Sensitivity=0.7660, Specificity=0.8576, Accuracy=0.8548, Precision=0.1457, F1=0.2449, MCC=0.2925, AUC=0.8973
#
# Average metrics over 5 folds:
# TP=402.8, FP=2750.6, TN=13968.0, FN=121.4
# Sensitivity=0.7680, Specificity=0.8355, Accuracy=0.8334, Precision=0.2212, F1=0.8826, MCC=0.2697, AUC=0.1294

# %% [markdown]
# ## New Independent Test Set

# %%
import numpy as np
x_train = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/train_data.npy", allow_pickle=True)
y_train = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/train_labels.npy", allow_pickle=True)
x_test = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/Indep_test_data.npy", allow_pickle=True)
y_test = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/Indep_test_labels.npy", allow_pickle=True)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test .shape)
# Out:
# (86214, 1, 15, 1024)
# (86214, 2)
# (2275, 1, 15, 1024)
# (2275, 2)

# %%
# Training code
if VALIDATION_MODE == "independent":
    # Check the shape of y_train
    print("Shape of y_train:", y_train.shape)

    # Initialize the data generator with the batch size
    generator = DataGenerator(x_train, y_train, batch_size=BATCH_SIZE)

    # Instantiate the AttentionOnlyModel
    model = PositionalAttention(
        feature_dim=NUM_FEATURE,     # Input feature dimension (1024)
        hidden_dim=HIDDEN_DIM,       # Hidden dimension for model
        num_heads=NUM_HEADS,         # Number of attention heads
        num_classes=NUM_CLASSES,     # Number of output classes (2)
        dropout_rate=DROPOUT         # Dropout rate
    )

    # Compile the model with categorical_crossentropy for one-hot encoded labels
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Build the model with the input shape expected by the DataGenerator
    model.build(input_shape=(BATCH_SIZE, SEQ_LENGTH, NUM_FEATURE))
    
    model.summary()

    # Train the model
    history = model.fit(generator, epochs=EPOCHS, verbose=1)

# Test the model
if VALIDATION_MODE == "independent":
    x_test_reshaped = x_test.reshape(-1, 15, 1024)  # Adjust this shape as needed
    print(f"Reshaped Test data shape: {x_test_reshaped.shape}")
    # Run the model test function directly with one-hot encoded y_test
    model_name = "PATN_New_Test Set" 
    model_test(model, x_test_reshaped, y_test, model_name)
# Out:
# Shape of y_train: (86214, 2)
# Model: "positional_attention"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding (Positi  multiple                 0
#  onalEncoding)
#
#  sequential (Sequential)     (32, 15, 512)             526848
#
#  self_attention (SelfAttenti  multiple                 787968
#  on)
#
#  sequential_1 (Sequential)   (32, 15, 512)             525312
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dense_6 (Dense)             multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2695/2695 [==============================] - 25s 9ms/step - loss: 0.1405 - accuracy: 0.9695
# Epoch 2/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.1243 - accuracy: 0.9695
# Epoch 3/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.1169 - accuracy: 0.9696
# Epoch 4/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.1137 - accuracy: 0.9695
# Epoch 5/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.1107 - accuracy: 0.9691
# Epoch 6/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.1072 - accuracy: 0.9696
# Epoch 7/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.1049 - accuracy: 0.9701
# Epoch 8/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.1081 - accuracy: 0.9715
# Epoch 9/25
# 2695/2695 [==============================] - 23s 9ms/step - loss: 0.1027 - accuracy: 0.9714
# Epoch 10/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.1041 - accuracy: 0.9726
# Epoch 11/25
# 2695/2695 [==============================] - 23s 8ms/step - loss: 0.1001 - accuracy: 0.9733
# Epoch 12/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0994 - accuracy: 0.9738
# Epoch 13/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0960 - accuracy: 0.9754
# Epoch 14/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0941 - accuracy: 0.9752
# Epoch 15/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0922 - accuracy: 0.9760
# Epoch 16/25
# 2695/2695 [==============================] - 21s 8ms/step - loss: 0.0935 - accuracy: 0.9754
# Epoch 17/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0947 - accuracy: 0.9749
# Epoch 18/25
# 2695/2695 [==============================] - 21s 8ms/step - loss: 0.0955 - accuracy: 0.9750
# Epoch 19/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0918 - accuracy: 0.9755
# Epoch 20/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0968 - accuracy: 0.9747
# Epoch 21/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0941 - accuracy: 0.9745
# Epoch 22/25
# 2695/2695 [==============================] - 21s 8ms/step - loss: 0.0955 - accuracy: 0.9735
# Epoch 23/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0975 - accuracy: 0.9726
# Epoch 24/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0971 - accuracy: 0.9736
# Epoch 25/25
# 2695/2695 [==============================] - 22s 8ms/step - loss: 0.0956 - accuracy: 0.9734
# Reshaped Test data shape: (2275, 15, 1024)
# Test data shape: (2275, 15, 1024)
# 72/72 [==============================] - 0s 3ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/PATN_New_Test Set.pkl
# Best Threshold=0.04821346327662468, G-Mean=0.8729076620900835
# TP=64, FP=183, TN=2015, FN=13, Sensitivity=0.8312, Specificity=0.9167, Accuracy=0.9138, Precision=0.2591, F1=0.3951, MCC=0.4347, AUC=0.9512

# %% [markdown]
# ## RAG Feature Fusion Test

# %%
import numpy as np
x_train = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/Rag_train_data_N.npy", allow_pickle=True)
y_train = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/train_labels.npy", allow_pickle=True)
x_test = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/Rag_test_data_N.npy", allow_pickle=True)
y_test = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/test_labels.npy", allow_pickle=True)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test .shape)
# Out:
# (86214, 1, 15, 1024)
# (86214, 2)
# (21208, 1, 15, 1024)
# (21208, 2)

# %%
# Training code for RAG Test Data
if VALIDATION_MODE == "independent":
    # Check the shape of y_train
    print("Shape of y_train:", y_train.shape)

    # Initialize the data generator with the batch size
    generator = DataGenerator(x_train, y_train, batch_size=BATCH_SIZE)

    # Instantiate the AttentionOnlyModel
    model = PositionalAttention(
        feature_dim=NUM_FEATURE,     # Input feature dimension (1024)
        hidden_dim=HIDDEN_DIM,       # Hidden dimension for model
        num_heads=NUM_HEADS,         # Number of attention heads
        num_classes=NUM_CLASSES,     # Number of output classes (2)
        dropout_rate=DROPOUT         # Dropout rate
    )

    # Compile the model with categorical_crossentropy for one-hot encoded labels
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Build the model with the input shape expected by the DataGenerator
    model.build(input_shape=(BATCH_SIZE, SEQ_LENGTH, NUM_FEATURE))
    
    model.summary()

    # Train the model
    history = model.fit(generator, epochs=EPOCHS, verbose=1)

# Test the model
if VALIDATION_MODE == "independent":
    x_test_reshaped = x_test.reshape(-1, 15, 1024)  # Adjust this shape as needed
    print(f"Reshaped Test data shape: {x_test_reshaped.shape}")
    # Run the model test function directly with one-hot encoded y_test
    model_name = "PATN_RAG_Test_N" 
    model_test(model, x_test_reshaped, y_test, model_name)
# Out:
# Shape of y_train: (86214, 2)
# Model: "positional_attention_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_6 (Posi  multiple                 0
#  tionalEncoding)
#
#  sequential_12 (Sequential)  (32, 15, 512)             526848
#
#  self_attention_6 (SelfAtten  multiple                 787968
#  tion)
#
#  sequential_13 (Sequential)  (32, 15, 512)             525312
#
#  global_average_pooling1d_6   multiple                 0
#  (GlobalAveragePooling1D)
#
#  dense_48 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2695/2695 [==============================] - 17s 6ms/step - loss: 0.1396 - accuracy: 0.9689
# Epoch 2/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.1194 - accuracy: 0.9704
# Epoch 3/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.1085 - accuracy: 0.9728
# Epoch 4/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.1011 - accuracy: 0.9741
# Epoch 5/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0989 - accuracy: 0.9746
# Epoch 6/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0941 - accuracy: 0.9757
# Epoch 7/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0927 - accuracy: 0.9763
# Epoch 8/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0926 - accuracy: 0.9762
# Epoch 9/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0905 - accuracy: 0.9770
# Epoch 10/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0892 - accuracy: 0.9776
# Epoch 11/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0905 - accuracy: 0.9774
# Epoch 12/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0914 - accuracy: 0.9776
# Epoch 13/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0910 - accuracy: 0.9762
# Epoch 14/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0908 - accuracy: 0.9771
# Epoch 15/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0876 - accuracy: 0.9768
# Epoch 16/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.1212 - accuracy: 0.9751
# Epoch 17/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0896 - accuracy: 0.9766
# Epoch 18/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0867 - accuracy: 0.9777
# Epoch 19/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0859 - accuracy: 0.9781
# Epoch 20/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0910 - accuracy: 0.9766
# Epoch 21/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0928 - accuracy: 0.9768
# Epoch 22/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0885 - accuracy: 0.9779
# Epoch 23/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0912 - accuracy: 0.9770
# Epoch 24/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0834 - accuracy: 0.9789
# Epoch 25/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0845 - accuracy: 0.9783
# Reshaped Test data shape: (21208, 15, 1024)
# Test data shape: (21208, 15, 1024)
# 663/663 [==============================] - 2s 3ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/PATN_RAG_Test_N.pkl
# Best Threshold=0.0667024478316307, G-Mean=0.8145429394888556
# TP=490, FP=2912, TN=17662, FN=144, Sensitivity=0.7729, Specificity=0.8585, Accuracy=0.8559, Precision=0.1440, F1=0.2428, MCC=0.2930, AUC=0.8810

# %%
##Cross Validation
VALIDATION_MODE="cross"
# Training code for the Cross-validation
if VALIDATION_MODE == "cross":
    # Check the shape of y_train
    print("Shape of y_train:", y_train.shape)

    # Initialize KFold
    kf = KFold(n_splits=K_FOLD, shuffle=True, random_state=42)

    # Store metrics for each fold
    metrics_list = []

    # Cross-validation loop
    for train_index, val_index in kf.split(x_train):
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

        # Print shapes for debugging
        print(f"Training on fold with shapes: {x_train_fold.shape}, {y_train_fold.shape}")
        print(f"Validation on fold with shapes: {x_val_fold.shape}, {y_val_fold.shape}")

        # Initialize the data generator for the training data
        generator = DataGenerator(x_train_fold, y_train_fold, batch_size=BATCH_SIZE)

        # Instantiate the AttentionOnlyModel
        model = PositionalAttention(
            feature_dim=NUM_FEATURE,     # Input feature dimension (1024)
            hidden_dim=HIDDEN_DIM,       # Hidden dimension for model
            num_heads=NUM_HEADS,         # Number of attention heads
            num_classes=NUM_CLASSES,     # Number of output classes (2)
            dropout_rate=DROPOUT         # Dropout rate
        )

        # Compile the model
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Build the model with the input shape expected by the DataGenerator
        model.build(input_shape=(BATCH_SIZE, SEQ_LENGTH, NUM_FEATURE))
        
        model.summary()

        # Train the model
        history = model.fit(generator, epochs=EPOCHS, verbose=1)  # Set verbose to 1 to see training progress

        # Reshape validation data before testing
        x_val_reshaped = x_val_fold.reshape(-1, 15, 1024)  # Adjust this shape to match model input
        print(f"Reshaped Validation data shape: {x_val_reshaped.shape}")

        # Evaluate the model on the validation set using the model test function
        model_name = f"PATN_RAG__N_Cross_fold_{len(metrics_list) + 1}"  # Create a unique name for the model
        metrics_result = model_test(model, x_val_reshaped, y_val_fold, model_name)  # Ensure y_val_fold is one-hot encoded if necessary

        # Store metrics for averaging
        metrics_list.append(metrics_result)

    # Compute average metrics
    average_metrics = np.mean(metrics_list, axis=0)

    # print(f"Average metrics over {K_FOLD} folds:")
    # print(f"TP={average_metrics[0]}, FP={average_metrics[1]}, TN={average_metrics[2]}, FN={average_metrics[3]}")
    # print(f"Sensitivity={average_metrics[4]:.4f}, Specificity={average_metrics[5]:.4f}, "
    #       f"Accuracy={average_metrics[6]:.4f}, Precision={average_metrics[7]:.4f}, "
    #       f"AUC={average_metrics[8]:.4f}, MCC={average_metrics[9]:.4f}, F1={average_metrics[10]:.4f}")
# Out:
# Shape of y_train: (86214, 2)
# Training on fold with shapes: (68971, 1, 15, 1024), (68971, 2)
# Validation on fold with shapes: (17243, 1, 15, 1024), (17243, 2)
# Model: "positional_attention_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_8 (Posi  multiple                 0
#  tionalEncoding)
#
#  sequential_16 (Sequential)  (32, 15, 512)             526848
#
#  self_attention_8 (SelfAtten  multiple                 787968
#  tion)
#
#  sequential_17 (Sequential)  (32, 15, 512)             525312
#
#  global_average_pooling1d_8   multiple                 0
#  (GlobalAveragePooling1D)
#
#  dense_62 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1399 - accuracy: 0.9698
# Epoch 2/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1177 - accuracy: 0.9701
# Epoch 3/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1130 - accuracy: 0.9707
# Epoch 4/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1095 - accuracy: 0.9718
# Epoch 5/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1085 - accuracy: 0.9726
# Epoch 6/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1094 - accuracy: 0.9710
# Epoch 7/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1040 - accuracy: 0.9734
# Epoch 8/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1019 - accuracy: 0.9738
# Epoch 9/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1031 - accuracy: 0.9738
# Epoch 10/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1008 - accuracy: 0.9743
# Epoch 11/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1031 - accuracy: 0.9733
# Epoch 12/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0988 - accuracy: 0.9739
# Epoch 13/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0967 - accuracy: 0.9752
# Epoch 14/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0962 - accuracy: 0.9750
# Epoch 15/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0950 - accuracy: 0.9757
# Epoch 16/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0957 - accuracy: 0.9758
# Epoch 17/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0923 - accuracy: 0.9765
# Epoch 18/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0980 - accuracy: 0.9746
# Epoch 19/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0903 - accuracy: 0.9766
# Epoch 20/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0916 - accuracy: 0.9763
# Epoch 21/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0904 - accuracy: 0.9768
# Epoch 22/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0908 - accuracy: 0.9771
# Epoch 23/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0901 - accuracy: 0.9765
# Epoch 24/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0886 - accuracy: 0.9776
# Epoch 25/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0888 - accuracy: 0.9770
# Reshaped Validation data shape: (17243, 15, 1024)
# Test data shape: (17243, 15, 1024)
# 539/539 [==============================] - 1s 2ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/PATN_RAG__N_Cross_fold_1.pkl
# Best Threshold=0.15750223398208618, G-Mean=0.7798119947478357
# TP=385, FP=2430, TN=14272, FN=156, Sensitivity=0.7116, Specificity=0.8545, Accuracy=0.8500, Precision=0.1368, F1=0.2294, MCC=0.2670, AUC=0.8669
#
# Training on fold with shapes: (68971, 1, 15, 1024), (68971, 2)
# Validation on fold with shapes: (17243, 1, 15, 1024), (17243, 2)
# Model: "positional_attention_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_9 (Posi  multiple                 0
#  tionalEncoding)
#
#  sequential_18 (Sequential)  (32, 15, 512)             526848
#
#  self_attention_9 (SelfAtten  multiple                 787968
#  tion)
#
#  sequential_19 (Sequential)  (32, 15, 512)             525312
#
#  global_average_pooling1d_9   multiple                 0
#  (GlobalAveragePooling1D)
#
#  dense_69 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1415 - accuracy: 0.9694
# Epoch 2/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1240 - accuracy: 0.9698
# Epoch 3/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1136 - accuracy: 0.9708
# Epoch 4/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1097 - accuracy: 0.9722
# Epoch 5/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1082 - accuracy: 0.9722
# Epoch 6/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1052 - accuracy: 0.9731
# Epoch 7/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1036 - accuracy: 0.9731
# Epoch 8/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1038 - accuracy: 0.9735
# Epoch 9/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1006 - accuracy: 0.9743
# Epoch 10/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0991 - accuracy: 0.9755
# Epoch 11/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0977 - accuracy: 0.9751
# Epoch 12/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0970 - accuracy: 0.9756
# Epoch 13/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0991 - accuracy: 0.9754
# Epoch 14/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0944 - accuracy: 0.9765
# Epoch 15/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0957 - accuracy: 0.9755
# Epoch 16/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0965 - accuracy: 0.9757
# Epoch 17/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0952 - accuracy: 0.9757
# Epoch 18/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0949 - accuracy: 0.9759
# Epoch 19/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0970 - accuracy: 0.9752
# Epoch 20/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0922 - accuracy: 0.9770
# Epoch 21/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0916 - accuracy: 0.9767
# Epoch 22/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0903 - accuracy: 0.9770
# Epoch 23/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0908 - accuracy: 0.9768
# Epoch 24/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0896 - accuracy: 0.9773
# Epoch 25/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0887 - accuracy: 0.9776
# Reshaped Validation data shape: (17243, 15, 1024)
# Test data shape: (17243, 15, 1024)
# 539/539 [==============================] - 2s 3ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/PATN_RAG__N_Cross_fold_2.pkl
# Best Threshold=0.12842866778373718, G-Mean=0.7934871525424189
# TP=414, FP=2909, TN=13791, FN=129, Sensitivity=0.7624, Specificity=0.8258, Accuracy=0.8238, Precision=0.1246, F1=0.2142, MCC=0.2605, AUC=0.8724
#
# Training on fold with shapes: (68971, 1, 15, 1024), (68971, 2)
# Validation on fold with shapes: (17243, 1, 15, 1024), (17243, 2)
# Model: "positional_attention_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_10 (Pos  multiple                 0
#  itionalEncoding)
#
#  sequential_20 (Sequential)  (32, 15, 512)             526848
#
#  self_attention_10 (SelfAtte  multiple                 787968
#  ntion)
#
#  sequential_21 (Sequential)  (32, 15, 512)             525312
#
#  global_average_pooling1d_10  multiple                 0
#   (GlobalAveragePooling1D)
#
#  dense_76 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1407 - accuracy: 0.9690
# Epoch 2/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1255 - accuracy: 0.9694
# Epoch 3/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1189 - accuracy: 0.9694
# Epoch 4/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1109 - accuracy: 0.9715
# Epoch 5/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1071 - accuracy: 0.9731
# Epoch 6/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1050 - accuracy: 0.9733
# Epoch 7/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1027 - accuracy: 0.9739
# Epoch 8/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1015 - accuracy: 0.9734
# Epoch 9/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0997 - accuracy: 0.9751
# Epoch 10/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0989 - accuracy: 0.9751
# Epoch 11/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0987 - accuracy: 0.9748
# Epoch 12/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0970 - accuracy: 0.9754
# Epoch 13/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0983 - accuracy: 0.9752
# Epoch 14/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0949 - accuracy: 0.9761
# Epoch 15/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0954 - accuracy: 0.9753
# Epoch 16/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0945 - accuracy: 0.9761
# Epoch 17/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0949 - accuracy: 0.9764
# Epoch 18/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0925 - accuracy: 0.9762
# Epoch 19/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0919 - accuracy: 0.9767
# Epoch 20/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0929 - accuracy: 0.9760
# Epoch 21/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0890 - accuracy: 0.9777
# Epoch 22/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0895 - accuracy: 0.9771
# Epoch 23/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0897 - accuracy: 0.9773
# Epoch 24/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0878 - accuracy: 0.9777
# Epoch 25/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0868 - accuracy: 0.9778
# Reshaped Validation data shape: (17243, 15, 1024)
# Test data shape: (17243, 15, 1024)
# 539/539 [==============================] - 2s 3ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/PATN_RAG__N_Cross_fold_3.pkl
# Best Threshold=0.07202120125293732, G-Mean=0.7987721405593727
# TP=378, FP=2215, TN=14514, FN=136, Sensitivity=0.7354, Specificity=0.8676, Accuracy=0.8637, Precision=0.1458, F1=0.2433, MCC=0.2869, AUC=0.8791
#
# Training on fold with shapes: (68971, 1, 15, 1024), (68971, 2)
# Validation on fold with shapes: (17243, 1, 15, 1024), (17243, 2)
# Model: "positional_attention_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_11 (Pos  multiple                 0
#  itionalEncoding)
#
#  sequential_22 (Sequential)  (32, 15, 512)             526848
#
#  self_attention_11 (SelfAtte  multiple                 787968
#  ntion)
#
#  sequential_23 (Sequential)  (32, 15, 512)             525312
#
#  global_average_pooling1d_11  multiple                 0
#   (GlobalAveragePooling1D)
#
#  dense_83 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1498 - accuracy: 0.9684
# Epoch 2/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1301 - accuracy: 0.9691
# Epoch 3/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1191 - accuracy: 0.9692
# Epoch 4/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1097 - accuracy: 0.9716
# Epoch 5/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1039 - accuracy: 0.9738
# Epoch 6/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0980 - accuracy: 0.9748
# Epoch 7/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0968 - accuracy: 0.9753
# Epoch 8/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0952 - accuracy: 0.9756
# Epoch 9/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0934 - accuracy: 0.9760
# Epoch 10/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0922 - accuracy: 0.9768
# Epoch 11/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0892 - accuracy: 0.9771
# Epoch 12/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0909 - accuracy: 0.9767
# Epoch 13/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0872 - accuracy: 0.9776
# Epoch 14/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0870 - accuracy: 0.9778
# Epoch 15/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0914 - accuracy: 0.9765
# Epoch 16/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0884 - accuracy: 0.9772
# Epoch 17/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0880 - accuracy: 0.9774
# Epoch 18/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0884 - accuracy: 0.9775
# Epoch 19/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.1000 - accuracy: 0.9750
# Epoch 20/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0850 - accuracy: 0.9781
# Epoch 21/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0870 - accuracy: 0.9777
# Epoch 22/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0853 - accuracy: 0.9780
# Epoch 23/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0852 - accuracy: 0.9782
# Epoch 24/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0851 - accuracy: 0.9779
# Epoch 25/25
# 2156/2156 [==============================] - 12s 6ms/step - loss: 0.0868 - accuracy: 0.9775
# Reshaped Validation data shape: (17243, 15, 1024)
# Test data shape: (17243, 15, 1024)
# 539/539 [==============================] - 1s 2ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/PATN_RAG__N_Cross_fold_4.pkl
# Best Threshold=0.06860358268022537, G-Mean=0.7998069761989646
# TP=386, FP=3065, TN=13685, FN=107, Sensitivity=0.7830, Specificity=0.8170, Accuracy=0.8160, Precision=0.1119, F1=0.1957, MCC=0.2499, AUC=0.8809
#
# Training on fold with shapes: (68972, 1, 15, 1024), (68972, 2)
# Validation on fold with shapes: (17242, 1, 15, 1024), (17242, 2)
# Model: "positional_attention_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_12 (Pos  multiple                 0
#  itionalEncoding)
#
#  sequential_24 (Sequential)  (32, 15, 512)             526848
#
#  self_attention_12 (SelfAtte  multiple                 787968
#  ntion)
#
#  sequential_25 (Sequential)  (32, 15, 512)             525312
#
#  global_average_pooling1d_12  multiple                 0
#   (GlobalAveragePooling1D)
#
#  dense_90 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1447 - accuracy: 0.9688
# Epoch 2/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1259 - accuracy: 0.9697
# Epoch 3/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1166 - accuracy: 0.9705
# Epoch 4/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1136 - accuracy: 0.9710
# Epoch 5/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1096 - accuracy: 0.9716
# Epoch 6/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1053 - accuracy: 0.9729
# Epoch 7/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1053 - accuracy: 0.9729
# Epoch 8/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1032 - accuracy: 0.9737
# Epoch 9/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1012 - accuracy: 0.9741
# Epoch 10/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.1011 - accuracy: 0.9742
# Epoch 11/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0982 - accuracy: 0.9753
# Epoch 12/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0986 - accuracy: 0.9752
# Epoch 13/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0966 - accuracy: 0.9753
# Epoch 14/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0950 - accuracy: 0.9762
# Epoch 15/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0959 - accuracy: 0.9760
# Epoch 16/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0932 - accuracy: 0.9765
# Epoch 17/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0924 - accuracy: 0.9764
# Epoch 18/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0914 - accuracy: 0.9773
# Epoch 19/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0904 - accuracy: 0.9769
# Epoch 20/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0907 - accuracy: 0.9772
# Epoch 21/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0893 - accuracy: 0.9772
# Epoch 22/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0897 - accuracy: 0.9773
# Epoch 23/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0903 - accuracy: 0.9770
# Epoch 24/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0899 - accuracy: 0.9771
# Epoch 25/25
# 2156/2156 [==============================] - 13s 6ms/step - loss: 0.0884 - accuracy: 0.9769
# Reshaped Validation data shape: (17242, 15, 1024)
# Test data shape: (17242, 15, 1024)
# 539/539 [==============================] - 1s 2ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/PATN_RAG__N_Cross_fold_5.pkl
# Best Threshold=0.060013145208358765, G-Mean=0.8158905303944657
# TP=424, FP=2806, TN=13906, FN=106, Sensitivity=0.8000, Specificity=0.8321, Accuracy=0.8311, Precision=0.1313, F1=0.2255, MCC=0.2796, AUC=0.8948
#
# Average metrics over 5 folds:
# TP=397.4, FP=2685.0, TN=14033.6, FN=126.8
# Sensitivity=0.7585, Specificity=0.8394, Accuracy=0.8369, Precision=0.2688, AUC=0.8788, MCC=0.2216, F1=0.1301

# %%
import numpy as np
x_train = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/Rag_train_data_N.npy", allow_pickle=True)
y_train = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/train_labels.npy", allow_pickle=True)
x_test = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/Rag_Indp_test_data_N.npy", allow_pickle=True)
y_test = np.load("C:/jupyter/Malik/Metal Binding/Metal_ProtTrans/Indep_test_labels.npy", allow_pickle=True)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test .shape)
# Out:
# (86214, 1, 15, 1024)
# (86214, 2)
# (2275, 1, 15, 1024)
# (2275, 2)

# %%
# Training code
VALIDATION_MODE="independent"
if VALIDATION_MODE == "independent":
    # Check the shape of y_train
    print("Shape of y_train:", y_train.shape)

    # Initialize the data generator with the batch size
    generator = DataGenerator(x_train, y_train, batch_size=BATCH_SIZE)

    # Instantiate the AttentionOnlyModel
    model = PositionalAttention(
        feature_dim=NUM_FEATURE,     # Input feature dimension (1024)
        hidden_dim=HIDDEN_DIM,       # Hidden dimension for model
        num_heads=NUM_HEADS,         # Number of attention heads
        num_classes=NUM_CLASSES,     # Number of output classes (2)
        dropout_rate=DROPOUT         # Dropout rate
    )

    # Compile the model with categorical_crossentropy for one-hot encoded labels
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Build the model with the input shape expected by the DataGenerator
    model.build(input_shape=(BATCH_SIZE, SEQ_LENGTH, NUM_FEATURE))
    
    model.summary()

    # Train the model
    history = model.fit(generator, epochs=EPOCHS, verbose=1)

# Test the model
if VALIDATION_MODE == "independent":
    x_test_reshaped = x_test.reshape(-1, 15, 1024)  # Adjust this shape as needed
    print(f"Reshaped Test data shape: {x_test_reshaped.shape}")
    # Run the model test function directly with one-hot encoded y_test
    model_name = "PATN_New_RAG_N_Test Set" 
    model_test(model, x_test_reshaped, y_test, model_name)
# Out:
# Shape of y_train: (86214, 2)
# Model: "positional_attention_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  positional_encoding_13 (Pos  multiple                 0
#  itionalEncoding)
#
#  sequential_26 (Sequential)  (32, 15, 512)             526848
#
#  self_attention_13 (SelfAtte  multiple                 787968
#  ntion)
#
#  sequential_27 (Sequential)  (32, 15, 512)             525312
#
#  global_average_pooling1d_13  multiple                 0
#   (GlobalAveragePooling1D)
#
#  dense_97 (Dense)            multiple                  1026
#
# =================================================================
# Total params: 1,841,154
# Trainable params: 1,841,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 2695/2695 [==============================] - 17s 6ms/step - loss: 0.1396 - accuracy: 0.9691
# Epoch 2/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.1209 - accuracy: 0.9696
# Epoch 3/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.1122 - accuracy: 0.9709
# Epoch 4/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.1085 - accuracy: 0.9728
# Epoch 5/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.1056 - accuracy: 0.9728
# Epoch 6/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.1013 - accuracy: 0.9744
# Epoch 7/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0984 - accuracy: 0.9752
# Epoch 8/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0990 - accuracy: 0.9752
# Epoch 9/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0951 - accuracy: 0.9764
# Epoch 10/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0924 - accuracy: 0.9771
# Epoch 11/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0908 - accuracy: 0.9771
# Epoch 12/25
# 2695/2695 [==============================] - 17s 6ms/step - loss: 0.0909 - accuracy: 0.9774
# Epoch 13/25
# 2695/2695 [==============================] - 17s 6ms/step - loss: 0.0926 - accuracy: 0.9766
# Epoch 14/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0896 - accuracy: 0.9777
# Epoch 15/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0872 - accuracy: 0.9778
# Epoch 16/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0864 - accuracy: 0.9776
# Epoch 17/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0899 - accuracy: 0.9773
# Epoch 18/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0867 - accuracy: 0.9778
# Epoch 19/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0848 - accuracy: 0.9784
# Epoch 20/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0853 - accuracy: 0.9781
# Epoch 21/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0837 - accuracy: 0.9786
# Epoch 22/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0853 - accuracy: 0.9776
# Epoch 23/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0846 - accuracy: 0.9784
# Epoch 24/25
# 2695/2695 [==============================] - 16s 6ms/step - loss: 0.0829 - accuracy: 0.9788
# Epoch 25/25
# 2695/2695 [==============================] - 17s 6ms/step - loss: 0.0833 - accuracy: 0.9790
# Reshaped Test data shape: (2275, 15, 1024)
# Test data shape: (2275, 15, 1024)
# 72/72 [==============================] - 0s 4ms/step
# ROC values saved to C:/jupyter/Malik/Metal Binding/Code/Roc/PATN_New_RAG_N_Test Set.pkl
# Best Threshold=0.058579493314027786, G-Mean=0.8941371418902226
# TP=69, FP=237, TN=1961, FN=8, Sensitivity=0.8961, Specificity=0.8922, Accuracy=0.8923, Precision=0.2255, F1=0.3603, MCC=0.4178, AUC=0.9586
